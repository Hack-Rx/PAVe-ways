# %%
import numpy as np
import joblib
from numpy import loadtxt
#import matplotlib.pyplot as plt
import pandas as pd
# random forest for making predictions for regression
from sklearn.datasets import make_regression
from sklearn.ensemble import RandomForestRegressor
from pprint import pprint
from csv import reader
from math import sqrt
from keras.models import Sequential
from keras.layers import Dense
from sklearn import preprocessing
from pickle import dump
from pickle import load
# Out:
# Using TensorFlow backend.

# %%
# define the keras model
model = RandomForestRegressor()
# Look at parameters used by our current forest
print('Parameters currently in use:\n')
pprint(model.get_params())
# Out:
# Parameters currently in use:
#
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'mse',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
#load the dataset
dataset= pd.read_csv('food_calorie_model2.csv', delimiter=',')

# %%
dataset.head()
# Out:
#   food-categories  food-code  quantity measure  measure-code  calories
# 0            Milk        101     225.0      ml             1       150
# 1          Paneer        102      60.0     gms             2       150
# 2          Butter        103       1.0    tbsp             3        45
# 3            Ghee        104       1.0    tbsp             3        45
# 4           Apple        201     242.0     gms             2       130

# %%
dataset
# Out:
#           food-categories  food-code  quantity measure  measure-code  calories
# 0                    Milk        101     225.0      ml             1       150
# 1                  Paneer        102      60.0     gms             2       150
# 2                  Butter        103       1.0    tbsp             3        45
# 3                    Ghee        104       1.0    tbsp             3        45
# 4                   Apple        201     242.0     gms             2       130
# 5                   Apple        201       1.0   small             4        55
# 6                  Banana        202       0.5  medium             5        55
# 7                  Banana        202     125.0     gms             2       110
# 8                  Grapes        203     125.0     gms             2        90
# 9                  Grapes        203      15.0   small             4        55
# 10                  Mango        204       0.5   small             4        55
# 11                Musambi        205       1.0  medium             5        55
# 12                 Orange        206     150.0     gms             2        80
# 13                 Orange        206       1.0  medium             5        55
# 14          Cooked Cereal        301       0.5     cup             7        80
# 15            Rice Cooked        302      25.0     gms             2        80
# 16               Chapatti        303       1.0  medium             5        80
# 17                 Potato        401     148.0     gms             2       110
# 18                 Potato        401       1.0  medium             5        80
# 19                    Dal        402       1.0   large             6        80
# 20       Mixed Vegetables        403     150.0     gms             2        80
# 21                   Fish        501      50.0     gms             2        55
# 22                 Mutton        502      30.0     gms             2        75
# 23                    Egg        503       1.0  medium             5        75
# 24        Biscuit (Sweet)        601      15.0     gms             2        70
# 25           Cake (Plain)        602      50.0     gms             2       135
# 26  Cake (Rich Chocolate)        603      50.0     gms             2       225
# 27           Dosa (Plain)        604       1.0  medium             5       135
# 28          Dosa (Masala)        605       1.0  medium             5       250
# 29                Pakoras        606      50.0     gms             2       175
# 30                   Puri        607       1.0   large             6        85
# 31                 Samosa        608       1.0  medium             5       140
# 32            Vada (Medu)        609       1.0   small             4        70
# 33       Biryani (Mutton)        701       1.0     cup             7       225
# 34         Biryani (Veg.)        702       1.0     cup             7       200
# 35        Curry (Chicken)        703     100.0     gms             2       225
# 36           Curry (Veg.)        704     100.0     gms             2       130
# 37             Fried Fish        705      85.0     gms             2       140
# 38           Pulav (Veg.)        706     100.0     gms             2       130
# 39           Carrot Halwa        801      45.0     gms             2       165
# 40                 Jalebi        802      20.0     gms             2       100
# 41                  Kheer        803     100.0     gms             2       180
# 42               Rasgulla        804      50.0     gms             2       140
# 43                   Beer        901    1250.0      ml             1        50
# 44                   Cola        902     200.0      ml             1        90
# 45                   Wine        903     100.0      ml             1        85

# %%
# split into input (X) and output (y) variables
X = dataset.iloc[:, [1,2,4,5]].values
y = dataset.iloc[:, 5].values
# Splitting the dataset into the Training set  and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
# Fit the model
history = model.fit(X, y)
# make class predictions with the model
predictions = model.predict(X)
# summarize the cases
for i in range(45):
	print('%s predicted = %d (expected %d)' % (X[i].tolist(), predictions[i], y[i]))
# Out:
# [101.0, 225.0, 1.0, 150.0] predicted = 147 (expected 150)
# [102.0, 60.0, 2.0, 150.0] predicted = 147 (expected 150)
# [103.0, 1.0, 3.0, 45.0] predicted = 46 (expected 45)
# [104.0, 1.0, 3.0, 45.0] predicted = 46 (expected 45)
# [201.0, 242.0, 2.0, 130.0] predicted = 132 (expected 130)
# [201.0, 1.0, 4.0, 55.0] predicted = 54 (expected 55)
# [202.0, 0.5, 5.0, 55.0] predicted = 55 (expected 55)
# [202.0, 125.0, 2.0, 110.0] predicted = 108 (expected 110)
# [203.0, 125.0, 2.0, 90.0] predicted = 88 (expected 90)
# [203.0, 15.0, 4.0, 55.0] predicted = 55 (expected 55)
# [204.0, 0.5, 4.0, 55.0] predicted = 54 (expected 55)
# [205.0, 1.0, 5.0, 55.0] predicted = 55 (expected 55)
# [206.0, 150.0, 2.0, 80.0] predicted = 79 (expected 80)
# [206.0, 1.0, 5.0, 55.0] predicted = 55 (expected 55)
# [301.0, 0.5, 7.0, 80.0] predicted = 80 (expected 80)
# [302.0, 25.0, 2.0, 80.0] predicted = 80 (expected 80)
# [303.0, 1.0, 5.0, 80.0] predicted = 80 (expected 80)
# [401.0, 148.0, 2.0, 110.0] predicted = 107 (expected 110)
# [401.0, 1.0, 5.0, 80.0] predicted = 80 (expected 80)
# [402.0, 1.0, 6.0, 80.0] predicted = 80 (expected 80)
# [403.0, 150.0, 2.0, 80.0] predicted = 80 (expected 80)
# [501.0, 50.0, 2.0, 55.0] predicted = 54 (expected 55)
# [502.0, 30.0, 2.0, 75.0] predicted = 74 (expected 75)
# [503.0, 1.0, 5.0, 75.0] predicted = 74 (expected 75)
# [601.0, 15.0, 2.0, 70.0] predicted = 70 (expected 70)
# [602.0, 50.0, 2.0, 135.0] predicted = 134 (expected 135)
# [603.0, 50.0, 2.0, 225.0] predicted = 227 (expected 225)
# [604.0, 1.0, 5.0, 135.0] predicted = 134 (expected 135)
# [605.0, 1.0, 5.0, 250.0] predicted = 237 (expected 250)
# [606.0, 50.0, 2.0, 175.0] predicted = 178 (expected 175)
# [607.0, 1.0, 6.0, 85.0] predicted = 83 (expected 85)
# [608.0, 1.0, 5.0, 140.0] predicted = 139 (expected 140)
# [609.0, 1.0, 4.0, 70.0] predicted = 71 (expected 70)
# [701.0, 1.0, 7.0, 225.0] predicted = 223 (expected 225)
# [702.0, 1.0, 7.0, 200.0] predicted = 195 (expected 200)
# [703.0, 100.0, 2.0, 225.0] predicted = 219 (expected 225)
# [704.0, 100.0, 2.0, 130.0] predicted = 130 (expected 130)
# [705.0, 85.0, 2.0, 140.0] predicted = 139 (expected 140)
# [706.0, 100.0, 2.0, 130.0] predicted = 130 (expected 130)
# [801.0, 45.0, 2.0, 165.0] predicted = 165 (expected 165)
# [802.0, 20.0, 2.0, 100.0] predicted = 95 (expected 100)
# [803.0, 100.0, 2.0, 180.0] predicted = 178 (expected 180)
# [804.0, 50.0, 2.0, 140.0] predicted = 139 (expected 140)
# [901.0, 1250.0, 1.0, 50.0] predicted = 51 (expected 50)
# [902.0, 200.0, 1.0, 90.0] predicted = 88 (expected 90)

# %%
# save the model
dump(model, open('food_calorie.pkl', 'wb'))
