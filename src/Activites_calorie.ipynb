# %%
import numpy as np
import joblib
from numpy import loadtxt
#import matplotlib.pyplot as plt
import pandas as pd
# random forest for making predictions for regression
from sklearn.datasets import make_regression
from sklearn.ensemble import RandomForestRegressor
from pprint import pprint
from csv import reader
from math import sqrt
from keras.models import Sequential
from keras.layers import Dense
from sklearn import preprocessing
from pickle import dump
from pickle import load
# Out:
# Using TensorFlow backend.

# %%
# define the keras model
model = RandomForestRegressor()
# Look at parameters used by our current forest
print('Parameters currently in use:\n')
pprint(model.get_params())
# Out:
# Parameters currently in use:
#
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'mse',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
#load the dataset
data= pd.read_csv('activity_calorie_model2.csv', delimiter=',')

# %%
data
# Out:
#                        Activity  Activity code  height(cms)  Weight(kgs)  \
# 0       Weight Lifting: general            101          160      56.6990
# 1       Weight Lifting: general            101          160      70.3068
# 2       Weight Lifting: general            101          160      83.9146
# 3        Stretching, Hatha Yoga            102          155      56.6990
# 4        Stretching, Hatha Yoga            102          155      70.3068
# ..                          ...            ...          ...          ...
# 73  Moving: household furniture            125          150      70.3068
# 74  Moving: household furniture            125          150      83.9146
# 75       Moving: carrying boxes            126          149      56.6990
# 76       Moving: carrying boxes            126          149      70.3068
# 77       Moving: carrying boxes            126          149      83.9146
#
#     calories burnt
# 0               90
# 1              112
# 2              133
# 3              120
# 4              149
# ..             ...
# 73             223
# 74             266
# 75             210
# 76             260
# 77             311
#
# [78 rows x 5 columns]

# %%
# split into input (X) and output (y) variables
X = data.iloc[:, 1:4].values
y = data.iloc[:, 4].values
# Splitting the dataset into the Training set  and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
# Fit the model
history = model.fit(X, y)
# make class predictions with the model
predictions = model.predict(X)
# summarize the cases
for i in range(77):
	print('%s predicted = %d (expected %d)' % (X[i].tolist(), predictions[i], y[i]))
# Out:
# [101.0, 160.0, 56.699] predicted = 104 (expected 90)
# [101.0, 160.0, 70.3068] predicted = 120 (expected 112)
# [101.0, 160.0, 83.9146] predicted = 148 (expected 133)
# [102.0, 155.0, 56.699] predicted = 121 (expected 120)
# [102.0, 155.0, 70.3068] predicted = 146 (expected 149)
# [102.0, 155.0, 83.9146] predicted = 174 (expected 178)
# [103.0, 180.0, 56.699] predicted = 137 (expected 135)
# [103.0, 180.0, 70.3068] predicted = 169 (expected 167)
# [103.0, 180.0, 83.9146] predicted = 201 (expected 200)
# [104.0, 172.0, 56.699] predicted = 147 (expected 150)
# [104.0, 172.0, 70.3068] predicted = 180 (expected 186)
# [104.0, 172.0, 83.9146] predicted = 218 (expected 222)
# [105.0, 165.0, 56.699] predicted = 156 (expected 165)
# [105.0, 165.0, 70.3068] predicted = 192 (expected 205)
# [105.0, 165.0, 83.9146] predicted = 231 (expected 244)
# [106.0, 146.0, 56.699] predicted = 188 (expected 210)
# [106.0, 146.0, 70.3068] predicted = 235 (expected 260)
# [106.0, 146.0, 83.9146] predicted = 272 (expected 311)
# [107.0, 148.0, 56.699] predicted = 106 (expected 90)
# [107.0, 148.0, 70.3068] predicted = 129 (expected 112)
# [107.0, 148.0, 83.9146] predicted = 159 (expected 133)
# [108.0, 178.0, 56.699] predicted = 127 (expected 120)
# [108.0, 178.0, 70.3068] predicted = 161 (expected 149)
# [108.0, 178.0, 83.9146] predicted = 193 (expected 178)
# [109.0, 166.0, 56.699] predicted = 125 (expected 120)
# [109.0, 166.0, 70.3068] predicted = 153 (expected 149)
# [109.0, 166.0, 83.9146] predicted = 187 (expected 178)
# [110.0, 165.0, 56.699] predicted = 135 (expected 135)
# [110.0, 165.0, 70.3068] predicted = 166 (expected 167)
# [110.0, 165.0, 83.9146] predicted = 201 (expected 200)
# [111.0, 160.0, 56.699] predicted = 133 (expected 135)
# [111.0, 160.0, 70.3068] predicted = 163 (expected 167)
# [111.0, 160.0, 83.9146] predicted = 195 (expected 200)
# [112.0, 146.0, 56.699] predicted = 155 (expected 150)
# [112.0, 146.0, 70.3068] predicted = 192 (expected 186)
# [112.0, 146.0, 83.9146] predicted = 224 (expected 222)
# [113.0, 178.0, 56.699] predicted = 167 (expected 165)
# [113.0, 178.0, 70.3068] predicted = 209 (expected 205)
# [113.0, 178.0, 83.9146] predicted = 244 (expected 244)
# [114.0, 167.0, 56.699] predicted = 203 (expected 240)
# [114.0, 167.0, 70.3068] predicted = 266 (expected 298)
# [114.0, 167.0, 83.9146] predicted = 314 (expected 355)
# [115.0, 149.0, 56.699] predicted = 145 (expected 135)
# [115.0, 149.0, 70.3068] predicted = 170 (expected 167)
# [115.0, 149.0, 83.9146] predicted = 202 (expected 200)
# [116.0, 155.0, 56.699] predicted = 137 (expected 139)
# [116.0, 155.0, 70.3068] predicted = 175 (expected 172)
# [116.0, 155.0, 83.9146] predicted = 202 (expected 205)
# [117.0, 161.0, 56.699] predicted = 35 (expected 19)
# [117.0, 161.0, 70.3068] predicted = 39 (expected 23)
# [117.0, 161.0, 83.9146] predicted = 53 (expected 28)
# [118.0, 170.0, 56.699] predicted = 26 (expected 23)
# [118.0, 170.0, 70.3068] predicted = 29 (expected 28)
# [118.0, 170.0, 83.9146] predicted = 46 (expected 33)
# [119.0, 167.0, 56.699] predicted = 41 (expected 34)
# [119.0, 167.0, 70.3068] predicted = 44 (expected 42)
# [119.0, 167.0, 83.9146] predicted = 66 (expected 50)
# [120.0, 179.0, 56.699] predicted = 79 (expected 75)
# [120.0, 179.0, 70.3068] predicted = 92 (expected 93)
# [120.0, 179.0, 83.9146] predicted = 102 (expected 111)
# [121.0, 151.0, 56.699] predicted = 125 (expected 120)
# [121.0, 151.0, 70.3068] predicted = 148 (expected 149)
# [121.0, 151.0, 83.9146] predicted = 174 (expected 178)
# [122.0, 170.0, 56.699] predicted = 134 (expected 135)
# [122.0, 170.0, 70.3068] predicted = 164 (expected 167)
# [122.0, 170.0, 83.9146] predicted = 187 (expected 200)
# [123.0, 149.0, 56.699] predicted = 155 (expected 150)
# [123.0, 149.0, 70.3068] predicted = 186 (expected 186)
# [123.0, 149.0, 83.9146] predicted = 213 (expected 222)
# [124.0, 167.0, 56.699] predicted = 154 (expected 150)
# [124.0, 167.0, 70.3068] predicted = 182 (expected 186)
# [124.0, 167.0, 83.9146] predicted = 211 (expected 222)
# [125.0, 150.0, 56.699] predicted = 188 (expected 180)
# [125.0, 150.0, 70.3068] predicted = 218 (expected 223)
# [125.0, 150.0, 83.9146] predicted = 251 (expected 266)
# [126.0, 149.0, 56.699] predicted = 216 (expected 210)
# [126.0, 149.0, 70.3068] predicted = 254 (expected 260)

# %%
# save the model
dump(model, open('activity_calorie.pkl', 'wb'))
